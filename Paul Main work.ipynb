# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("austin-animal-center-statistics-oct-1-2013-to-dec-7-2017-QueryResult (25).csv")
df=df.loc[df['monthyear'] != '2017-12']


df
# Out:
#       animal_id     name             datetime monthyear date_of_birth  \
# 0       A006100    Scamp  2014-03-08T17:10:00   2014-03    2007-07-09
# 1       A006100    Scamp  2014-12-20T16:35:00   2014-12    2007-07-09
# 2       A191351  Bri-Bri  2015-11-17T13:29:00   2015-11    1999-08-21
# 3       A322813    Tyson  2015-03-13T13:49:00   2015-03    2003-03-26
# 4       A552798     Phil  2015-04-09T16:12:00   2015-04    2007-08-21
# ...         ...      ...                  ...       ...           ...
# 75949   A762939      NaN  2017-11-30T00:00:00   2017-11    2017-09-30
# 75966   A762963     Bane  2017-11-30T17:52:00   2017-11    2016-11-30
# 75974   A762974    Daisy  2017-11-30T19:45:00   2017-11    2015-11-30
# 75975   A762976     Roxy  2017-11-30T19:45:00   2017-11    2015-11-30
# 75976   A762981      NaN  2017-11-30T19:46:00   2017-11    2015-11-30
#
#           outcome_type outcome_subtype animal_type sex_upon_outcome  \
# ...

# %%
a=df[df.outcome_type=='Return to Owner'].groupby('animal_id').count()
plt.hist(a.name,bins=[1,2,3,4,5,6])
plt.title("Total number of times an animal has been returned to their owner")
# Out:
# Text(0.5, 1.0, 'Total number of times an animal has been returned to their owner')

# %%
a[a.name>4]
df[df.animal_id=='A721033']
# Out:
#       animal_id     name             datetime monthyear date_of_birth  \
# 40998   A721033  Lil Bit  2017-01-28T15:22:00   2017-01    2015-05-20
# 40999   A721033  Lil Bit  2017-01-10T16:20:00   2017-01    2015-05-20
# 41000   A721033  Lil Bit  2016-09-12T13:40:00   2016-09    2015-05-20
# 41003   A721033  Lil Bit  2016-02-20T16:18:00   2016-02    2015-05-20
# 41004   A721033  Lil Bit  2017-02-07T17:26:00   2017-02    2015-05-20
# 41005   A721033  Lil Bit  2017-03-16T12:50:00   2017-03    2015-05-20
# 41006   A721033  Lil Bit  2016-10-21T18:55:00   2016-10    2015-05-20
# 41007   A721033  Lil Bit  2016-12-16T11:32:00   2016-12    2015-05-20
# 41008   A721033  Lil Bit  2016-07-11T17:44:00   2016-07    2015-05-20
# 41009   A721033  Lil Bit  2017-02-02T11:19:00   2017-02    2015-05-20
#
#           outcome_type outcome_subtype animal_type sex_upon_outcome  \
# 40998  Return to Owner             NaN         Dog    Neutered Male
# ...

# %%
a[a.name>4]
df[df.animal_id=='A706536']
# Out:
#       animal_id   name             datetime monthyear date_of_birth  \
# 29260   A706536  Butch  2016-11-29T12:26:00   2016-11    2010-06-30
# 29261   A706536  Butch  2015-07-30T16:27:00   2015-07    2010-06-30
# 29262   A706536  Butch  2015-10-28T11:34:00   2015-10    2010-06-30
# 29263   A706536  Butch  2016-01-11T12:46:00   2016-01    2010-06-30
# 29264   A706536  Butch  2015-07-03T12:49:00   2015-07    2010-06-30
# 29265   A706536  Butch  2016-02-22T10:49:00   2016-02    2010-06-30
# 29266   A706536  Butch  2015-07-20T12:50:00   2015-07    2010-06-30
# 29267   A706536  Butch  2016-03-29T14:23:00   2016-03    2010-06-30
# 29268   A706536  Butch  2016-03-18T19:32:00   2016-03    2010-06-30
# 29270   A706536  Butch  2015-12-26T13:41:00   2015-12    2010-06-30
# 29271   A706536  Butch  2016-02-19T19:15:00   2016-02    2010-06-30
#
#           outcome_type outcome_subtype animal_type sex_upon_outcome  \
# 29260         Transfer         Partner         Dog    Neutered Male
# ...

# %%
a[a.name>4]
# Out:
#            name  datetime  monthyear  date_of_birth  outcome_type  \
# animal_id
# A462580       5         5          5              5             5
# A593109       5         5          5              5             5
# A593537       5         5          5              5             5
# A613676       5         5          5              5             5
# A616444       8         8          8              8             8
# A623219       5         5          5              5             5
# A623561       5         5          5              5             5
# A642692       5         5          5              5             5
# A665334       5         5          5              5             5
# A667894       5         5          5              5             5
# A670612       7         7          7              7             7
# A671704       7         7          7              7             7
# A676423       5         5          5              5             5
# ...

# %%
df.groupby('animal_type').mean()
# Out:
#                      age
# animal_type
# Bird          482.595611
# Cat           523.837788
# Dog          1041.367389
# Livestock     491.111111
# Other         447.345975

# %%
print(df[df.outcome_type=="Euthanasia"].mean())
print(df[df.outcome_type=="Adoption"].mean())
print(df[df.outcome_type=="Return to Owner"].mean())
# Out:
# age    942.560068
# dtype: float64
# age    646.696906
# dtype: float64
# age    1505.849496
# dtype: float64

# %%
df[df.outcome_type=='Return to Owner'].groupby('animal_type').count()
# Out:
#              animal_id   name  datetime  monthyear  date_of_birth  \
# animal_type
# Bird                 9      7         9          9              9
# Cat               1346   1225      1346       1346           1346
# Dog              12210  11910     12210      12210          12210
# Livestock            1      0         1          1              1
# Other               35     21        35         35             35
#
#              outcome_type  outcome_subtype  sex_upon_outcome  \
# animal_type
# Bird                    9                0                 9
# Cat                  1346                0              1346
# Dog                 12210                0             12209
# Livestock               1                0                 1
# Other                  35                0                35
#
#              age_upon_outcome  breed  color    age
# animal_type
# Bird                        9      9      9      9
# Cat                      1346   1346   1346   1346
# ...

# %%
df[df.outcome_type=='Adoption'].groupby('animal_type').count()
# Out:
#              animal_id   name  datetime  monthyear  date_of_birth  \
# animal_type
# Bird               111     40       111        111            111
# Cat              12029  10029     12029      12029          12029
# Dog              18914  15863     18914      18914          18914
# Livestock            2      0         2          2              2
# Other              195    166       195        195            195
#
#              outcome_type  outcome_subtype  sex_upon_outcome  \
# animal_type
# Bird                  111               18               111
# Cat                 12029             3333             12029
# Dog                 18914             2313             18914
# Livestock               2                2                 2
# Other                 195               19               195
#
#              age_upon_outcome  breed  color    age
# animal_type
# Bird                      111    111    111    111
# Cat                     12029  12029  12029  12029
# ...

# %%
df[df.outcome_type=='Euthanasia'].groupby('animal_type').count()
# Out:
#              animal_id  name  datetime  monthyear  date_of_birth  \
# animal_type
# Bird                83     4        83         83             83
# Cat               1410   310      1410       1410           1410
# Dog               1480  1025      1480       1480           1480
# Other             2912    16      2912       2912           2912
#
#              outcome_type  outcome_subtype  sex_upon_outcome  \
# animal_type
# Bird                   83               79                83
# Cat                  1410             1399              1410
# Dog                  1480             1475              1480
# Other                2912             2764              2912
#
#              age_upon_outcome  breed  color   age
# animal_type
# Bird                       83     83     83    83
# Cat                      1410   1410   1410  1410
# Dog                      1480   1480   1480  1480
# Other                    2912   2912   2912  2912

# %%
adoption=df[df.outcome_type=="Adoption"].groupby('monthyear').count()
adoptionDog=df[df.outcome_type=="Adoption"][df.animal_type=="Dog"].groupby('monthyear').count()
adoptionCat=df[df.outcome_type=="Adoption"][df.animal_type=="Cat"].groupby('monthyear').count()
adoptionOther=df[df.outcome_type=="Adoption"][df.animal_type=="Other"].groupby('monthyear').count()
adoptionCat
# Out:
# c:\users\2212961\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\2212961\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\2212961\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#            animal_id  name  datetime  date_of_birth  outcome_type  \
# monthyear
# 2013-10          241   214       241            241           241
# 2013-11          227   202       227            227           227
# 2013-12          278   252       278            278           278
# ...

# %%
myaxis=["2013-12","2014-6","2014-12","2015-6","2015-12","2016-6","2016-12","2017-6","2-17-12"]
plt.plot(adoption.index, adoption.animal_id,label="total")
plt.plot(adoptionDog.index, adoptionDog.animal_id, label="Dog")
plt.plot(adoptionCat.index, adoptionCat.animal_id, label="Cat")
plt.grid()
plt.legend()
plt.xticks([0,6,12,18,24,30,36,42,48],myaxis,rotation=90)
plt.ylim(0,1000)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
euthanasia=df[df.outcome_type=="Euthanasia"].groupby('monthyear').count()
euthansiaDog=df[df.outcome_type=="Euthanasia"][df.animal_type=='Dog'].groupby('monthyear').count()
euthansiaCat=df[df.outcome_type=="Euthanasia"][df.animal_type=='Cat'].groupby('monthyear').count()
euthansiaOther=df[df.outcome_type=="Euthanasia"][df.animal_type=='Other'].groupby('monthyear').count()
# Out:
# c:\users\2212961\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\2212961\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\2212961\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
plt.plot(euthanasia.index, euthanasia.animal_id,label="total")
plt.plot(euthansiaOther.index, euthansiaOther.animal_id, label="Other")

plt.grid()
plt.legend()
plt.xticks([0,6,12,18,24,30,36,42,48],myaxis,rotation=90)
plt.ylim(0,300)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(euthansiaDog.index, euthansiaDog.animal_id, label="Dog")
plt.plot(euthansiaCat.index, euthansiaCat.animal_id, label="Cat")
plt.grid()
plt.legend()
plt.xticks([0,6,12,18,24,30,36,42,48],myaxis,rotation=90)
plt.ylim(0,100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
euthanasia.plot(y="animal_id",use_index=True)
euthansiaDog.plot(y="animal_id",use_index=True)
euthansiaCat.plot(y="animal_id",use_index=True)
euthansiaOther.plot(y="animal_id",use_index=True)
